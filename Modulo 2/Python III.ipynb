# %% [markdown]
# # <span style="color:blue">Programação Python para Ciência de Dados</span>
# ## <span style="color:blue">Módulo 2: Python III</span>
# ---

# %% [markdown]
# __Conteúdos:__
# - Progamação Orientada a Objeto
# - Classes e Objetos
# - Exceções
# - Módulos e Pacotes
#
# __Referências:__
# - Mark Lutz, Learning Python, O'Reilly, 2013
# - Eric Matthes, Python Crash Course: A Hands-On, Project-Based Introduction to Programming, No Starch Press, 2015

# %% [markdown]
# ---
# ## Programação Orientada a Objeto
# Três conceitos principais:
# - Objetos
# - Classes
# - Herança

# %% [markdown]
# ### Objetos
# Um objeto agrega dois conceitos:
# - Estado
# - Comportamento
#
#
# _Estado_ diz respeio às informações salvas nos _atributos_ do objeto
# <br><br>
# _Comportamento_ é manifestado através de funções (_métodos_) associadas ao objeto
#
# Várias linguagens de programação escondem estados internos e os fazem acessíveis apenas através de métodos<br>
#
# Python não faz isso. Tudo é exposto!!

# %% [markdown]
# ### Classes
# Uma classe é um protótipo para criar um objeto. Quando um objeto é criado a partir de um protótipo, diz-se que ele foi instaciado.
#
# Em termos de programação, uma classe especifica os atributos e métodos do objeto, que pode se manifestar em várias instâncias.
#
# __OBS__: Apesar de que _objetos_ e _instâncias_ não são a mesma coisa, nós usaremos as duas palavras como sinônimas.

# %% [markdown]
# ### Herança
# Classes são capazes de herdar estados e comportamentos de outras classes.<br>
# Uma classe que herda de outra classe é chamada subclasse. <br>
# Uma classe que é herdada por outra é chamada de superclasse ou classe base.

# %% [markdown]
# ---
# ## Classes em Python
# __Sintaxe__
# ```python
# class name_of_the_class(superclass,...)
#       attribute1 = value1
#       attribute2 = value2
#       :
#       :
#       def __init__(self,...):  # construtor da classe
#          … default code …
#
#       def method1(self,...):
#          self.attribute1 = value
# ```
# Um _atributo de classe_ é uma variável que é acessível por qualquer instância da classe.<br>
# Um _atributo de uma instância_ só é acessível pela intância que o criou (como uma variável local).

# %%
# Protótipo de classe
class bicycle():
    def __init__(self, bike_type = None, n_gears = 1, handlebar = 'Drop'):
        print("...building the object...")
        self.bicycle_type = bike_type # -> crinado atributos
        self.number_of_gears = n_gears
        self.handlebar_type = handlebar
        self.handle_options = ['Drop','Cruiser','Flat','Bullhorn']
    
    def get_handlebar_options(self,k=4):
        print(self.handle_options[:k])
        
    def __repr__(self): # double underscore -> método que vai executar alguma coisa
        return('Type: '+str(self.bicycle_type)+'\n'
               'Gears: '+str(self.number_of_gears)+'\n'
               'Handle: '+str(self.handlebar_type))

# %%
# objeto da classe bicycle é instanciado
my_bike = bicycle() 

# acessando variável da instância
my_bike.bicycle_type = 'Cruise' 
my_bike.number_of_gears = 3     

# acessando método da instância
my_bike.get_handlebar_options() 
my_bike.get_handlebar_options(2)

# instanciando com parâmetros
thy_bike = bicycle(bike_type='Speed',handlebar='Bullhorn') 

print(thy_bike)
# Out:
# ...building the object...
# ['Drop', 'Cruiser', 'Flat', 'Bullhorn']
# ['Drop', 'Cruiser']
# ...building the object...
# Type: Speed
# Gears: 1
# Handle: Bullhorn

# %%
class mountain_bike(bicycle): # herda bicycle como superclasse
    def __init__(self):
        bicycle.__init__(self,bike_type='Mountain',n_gears = 10,handlebar='Bullhorn')
        self.set_handlebar_options()
        
    def set_handlebar_options(self): 
        self.handle_options.remove('Cruiser')

# %%
my_mountain_bike = mountain_bike()
my_mountain_bike.get_handlebar_options()

print(my_mountain_bike)
# Out:
# ...building the object...
# ['Drop', 'Flat', 'Bullhorn']
# Type: Mountain
# Gears: 10
# Handle: Bullhorn

# %% [markdown]
# ### Sobrecarga de operador (Operator Overloading)
# Classes podem interceptar operadores especiais em Python. Métodos com nomes entre duplo underscore são casos especiais.
#
# Classes podem sobrepor a maioria das operações padrão de tipos
# - \__init\__ construtor de objeto object constructor
# - \__repr\__ chamado quanto objeto é escrito ou covertido em string (ex: print(instancia))
# - \__add\__ para o operador de soma +
# - \__lt\__, \__gt\__, para comparações X < Y, X > Y
# - e outras...

# %%
class bicycle():
    def __init__(self,bike_type = None,n_gears = 1,handlebar = 'Drop'):
        print("...building the object...")
        self.bicycle_type = bike_type
        self.number_of_gears = n_gears
        self.handlebar_type = handlebar
        self.handle_options = ['Drop','Cruiser','Flat','Bullhorn']
    
    def __repr__(self):      # including a default print in the superclass
        return('Type: '+self.bicycle_type+'\n'+
               'Gears: '+str(self.number_of_gears)+'\n'+
               'Handlebar: '+self.handlebar_type)
    
    def get_handlebar_options(self,k=4):
        print(self.handle_options[:k])

# %%
class mountain_bike(bicycle): # inherit bicycle as superclass
    def __init__(self,suspension = None):
        bicycle.__init__(self,bike_type='Mountain',n_gears = 10,handlebar='Bullhorn')
        self.set_handlebar_options()
        self.suspension_type = suspension
        
    def set_handlebar_options(self): 
        self.handle_options.remove('Cruiser')

# %%
my_mountain_bike = mountain_bike(suspension = 'downhill')
print(my_mountain_bike)
# Out:
# ...building the object...
# Type: Mountain
# Gears: 10
# Handlebar: Bullhorn

# %% [markdown]
# Note que a função **\_\_repr\_\_** na superclasse não inclui informações sobre o atributo suspension, portanto precisamos estender (em vez de substituir) a função **\_\_repr\_\_**.

# %%
class mountain_bike(bicycle): # inherit bicycle as superclass
    def __init__(self,suspension = None):
        bicycle.__init__(self,bike_type='Mountain',n_gears = 10,handlebar='Bullhorn')
        self.set_handlebar_options()
        self.suspension_type = suspension
        
    def __repr__(self):
        return(bicycle.__repr__(self)+'\n'
               +'Suspension: '+self.suspension_type)
        
    def set_handlebar_options(self): 
        self.handle_options.remove('Cruiser')

# %%
my_mountain_bike = mountain_bike(suspension = 'downhill')
print(my_mountain_bike)
# Out:
# ...building the object...
# Type: Mountain
# Gears: 10
# Handle: Bullhorn
# Suspension: downhill

# %% [markdown]
# ### Atributos públicos e privados
# Embora todos os atributos e métodos em Python são expostos, há uma convenção de que tudo precedido por dois underscores é privado.
# - \_\_uma_funcao
# - \_\_minha_variavel
#
# Internamente, eles são subtituidos por um nome que inclui o nome da classe
# - \_nomedaclasse\_\_uma_funcao
# - \_nomedaclasse\_\_minha_variavel
#
#
# Tudo precedido com um underscore é semi-privado, e você deveria se sentir culpado por acessar esse dado diretamente
# - \_b

# %%
class bicycle_private():
    def __init__(self,bike_type = None,n_gears = 1,handlebar = 'Drop'):
        print("...building the object...")
        self.bicycle_type = bike_type
        self.number_of_gears = n_gears
        self.handlebar_type = handlebar
        self.handle_options = ['Drop','Cruiser','Flat','Bullhorn']
        self.__this_is_private = None   # variável privada que onde o nome da classe é adicionada
                                        # _bicycle_private__this_is_private
            
    def get_private(self):
        print(self.__this_is_private)

# %%
thy_bicycle_private = bicycle_private()
thy_bicycle_private._bicycle_private__this_is_private = 0
thy_bicycle_private.get_private()
print(thy_bicycle_private._bicycle_private__this_is_private)
# Out:
# ...building the object...
# 0
# 0

# %%
thy_bicycle_private1 = bicycle_private()
thy_bicycle_private1.__this_is_private = 0 # criar dinamicamente um novo atributo
thy_bicycle_private1.get_private()
print(thy_bicycle_private1.__this_is_private)
# Out:
# ...building the object...
# None
# 0

# %%
thy_bicycle_private1.a = 'new'
print(thy_bicycle_private1.a)
# Out:
# new

# %% [markdown]
# ---
# ## Módulos e Pacotes
# Um _módulo_ (module) é um arquivo único que pode ser importado com o comando _import_. Essencialmente qualquer arquivo em Python é um módulo.
# ```python
# import my_module
# ```
# Um pacote é um módulo que contem vários módulos, podendo incluir outros subpacotes.
#
# ```python
# import numpy.random
# import numpy.linalg
# ```

# %% [markdown]
# ### Escopo de Atributos e Métodos em Módulos
# - Atributos e métodos de um módulo são acessado usando a sintaxe `modulo.atributo` e `modulo.metodo`
# - O conteúdo de módulos podem ser acessado pelo atributo \__dict\__ de um módulo ou usando `dir(modulo)`

# %%
import sys
sys.__dict__ # presente em todos os módulos
# Out:
# {'__name__': 'sys',
#  '__doc__': "This module provides access to some objects used or maintained by the\ninterpreter and to functions that interact strongly with the interpreter.\n\nDynamic objects:\n\nargv -- command line arguments; argv[0] is the script pathname if known\npath -- module search path; path[0] is the script directory, else ''\nmodules -- dictionary of loaded modules\n\ndisplayhook -- called to show results in an interactive session\nexcepthook -- called to handle any uncaught exception other than SystemExit\n  To customize printing in an interactive session or to install a custom\n  top-level exception handler, assign other functions to replace these.\n\nstdin -- standard input file object; used by input()\nstdout -- standard output file object; used by print()\nstderr -- standard error object; used for error messages\n  By assigning other file objects (or objects that behave like files)\n  to these, it is possible to redirect all of the interpreter's I/O.\n\nlast_type -- type of last uncaught exception\nlast_value -- value of last uncaught exception\nlast_traceback -- traceback of last uncaught exception\n  These three are only available in an interactive session after a\n  traceback has been printed.\n\nStatic objects:\n\nbuiltin_module_names -- tuple of module names built into this interpreter\ncopyright -- copyright notice pertaining to this interpreter\nexec_prefix -- prefix used to find the machine-specific Python library\nexecutable -- absolute path of the executable binary of the Python interpreter\nfloat_info -- a struct sequence with information about the float implementation.\nfloat_repr_style -- string indicating the style of repr() output for floats\nhash_info -- a struct sequence with information about the hash algorithm.\nhexversion -- version information encoded as a single integer\nimplementation -- Python implementation information.\nint_info -- a struct sequence with information about the int implementation.\nmaxsize -- the largest supported length of containers.\nmaxunicode -- the value of the largest Unicode code point\nplatform -- platform identifier\nprefix -- prefix used to find the Python library\nthread_info -- a struct sequence with information about the thread implementation.\nversion -- the version of this interpreter as a string\nversion_info -- version information as a named tuple\n__stdin__ -- the original stdin; don't touch!\n__stdout__ -- the original stdout; don't touch!\n__stderr__ -- the original stderr; don't touch!\n__displayhook__ -- the original displayhook; don't touch!\n__excepthook__ -- the original excepthook; don't touch!\n\nFunctions:\n\ndisplayhook() -- print an object to the screen, and save it in builtins._\nexcepthook() -- print an exception and its traceback to sys.stderr\nexc_info() -- return thread-safe information about the current exception\nexit() -- exit the interpreter by raising SystemExit\ngetdlopenflags() -- returns flags to be used for dlopen() calls\ngetprofile() -- get the global profiling function\ngetrefcount() -- return the reference count for an object (plus one :-)\ngetrecursionlimit() -- return the max recursion depth for the interpreter\ngetsizeof() -- return the size of an object in bytes\ngettrace() -- get the global debug tracing function\nsetcheckinterval() -- control how often the interpreter checks for events\nsetdlopenflags() -- set the flags to be used for dlopen() calls\nsetprofile() -- set the global profiling function\nsetrecursionlimit() -- set the max recursion depth for the interpreter\nsettrace() -- set the global debug tracing function\n",
#  '__package__': '',
#  '__loader__': _frozen_importlib.BuiltinImporter,
#  '__spec__': ModuleSpec(name='sys', loader=<class '_frozen_importlib.BuiltinImporter'>),
#  'breakpointhook': <function sys.breakpointhook>,
#  'callstats': <function sys.callstats>,
#  '_clear_type_cache': <function sys._clear_type_cache>,
#  '_current_frames': <function sys._current_frames>,
#  'displayhook': <ipykernel.displayhook.ZMQShellDisplayHook at 0x7f1ec06c2a58>,
#  'exc_info': <function sys.exc_info>,
#  'excepthook': <bound method InteractiveShell.excepthook of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f1ec2f55c18>>,
#  'exit': <function sys.exit>,
#  'getdefaultencoding': <function sys.getdefaultencoding>,
#  'getdlopenflags': <function sys.getdlopenflags>,
#  'getallocatedblocks': <function sys.getallocatedblocks>,
#  'getfilesystemencoding': <function sys.getfilesystemencoding>,
#  'getfilesystemencodeerrors': <function sys.getfilesystemencodeerrors>,
#  'getrefcount': <function sys.getrefcount>,
#  'getrecursionlimit': <function sys.getrecursionlimit>,
#  'getsizeof': <function sys.getsizeof>,
#  '_getframe': <function sys._getframe>,
#  'intern': <function sys.intern>,
#  'is_finalizing': <function sys.is_finalizing>,
#  'setcheckinterval': <function sys.setcheckinterval>,
#  'getcheckinterval': <function sys.getcheckinterval>,
#  'setswitchinterval': <function sys.setswitchinterval>,
#  'getswitchinterval': <function sys.getswitchinterval>,
#  'setdlopenflags': <function sys.setdlopenflags>,
#  'setprofile': <function sys.setprofile>,
#  'getprofile': <function sys.getprofile>,
#  'setrecursionlimit': <function sys.setrecursionlimit>,
#  'settrace': <function sys.settrace>,
#  'gettrace': <function sys.gettrace>,
#  'call_tracing': <function sys.call_tracing>,
#  '_debugmallocstats': <function sys._debugmallocstats>,
#  'set_coroutine_origin_tracking_depth': <function sys.set_coroutine_origin_tracking_depth(depth)>,
#  'get_coroutine_origin_tracking_depth': <function sys.get_coroutine_origin_tracking_depth()>,
#  'set_coroutine_wrapper': <function sys.set_coroutine_wrapper>,
#  'get_coroutine_wrapper': <function sys.get_coroutine_wrapper>,
#  'set_asyncgen_hooks': <function sys.set_asyncgen_hooks>,
#  'get_asyncgen_hooks': <function sys.get_asyncgen_hooks>,
#  '__displayhook__': <function sys.displayhook>,
#  '__excepthook__': <function sys.excepthook>,
#  '__breakpointhook__': <function sys.breakpointhook>,
#  'version': '3.7.3 (default, Mar 27 2019, 22:11:17) \n[GCC 7.3.0]',
#  'hexversion': 50791408,
#  '_git': ('CPython', '', ''),
#  '_framework': '',
#  'api_version': 1013,
#  'copyright': 'Copyright (c) 2001-2019 Python Software Foundation.\nAll Rights Reserved.\n\nCopyright (c) 2000 BeOpen.com.\nAll Rights Reserved.\n\nCopyright (c) 1995-2001 Corporation for National Research Initiatives.\nAll Rights Reserved.\n\nCopyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.\nAll Rights Reserved.',
#  'platform': 'linux',
#  'maxsize': 9223372036854775807,
#  'float_info': sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1),
#  'int_info': sys.int_info(bits_per_digit=30, sizeof_digit=4),
#  'hash_info': sys.hash_info(width=64, modulus=2305843009213693951, inf=314159, nan=0, imag=1000003, algorithm='siphash24', hash_bits=64, seed_bits=128, cutoff=0),
#  'maxunicode': 1114111,
#  'builtin_module_names': ('_abc',
#   '_ast',
#   '_codecs',
#   '_collections',
#   '_functools',
#   '_imp',
#   '_io',
#   '_locale',
#   '_operator',
#   '_signal',
#   '_sre',
#   '_stat',
#   '_string',
#   '_symtable',
#   '_thread',
#   '_tracemalloc',
#   '_warnings',
#   '_weakref',
#   'atexit',
#   'builtins',
#   'errno',
#   'faulthandler',
#   'gc',
#   'itertools',
#   'marshal',
#   'posix',
#   'pwd',
#   'sys',
#   'time',
#   'xxsubtype',
#   'zipimport'),
#  'byteorder': 'little',
#  'abiflags': 'm',
#  'version_info': sys.version_info(major=3, minor=7, micro=3, releaselevel='final', serial=0),
#  'implementation': namespace(_multiarch='x86_64-linux-gnu', cache_tag='cpython-37', hexversion=50791408, name='cpython', version=sys.version_info(major=3, minor=7, micro=3, releaselevel='final', serial=0)),
#  'flags': sys.flags(debug=0, inspect=0, interactive=0, optimize=0, dont_write_bytecode=0, no_user_site=0, no_site=0, ignore_environment=0, verbose=0, bytes_warning=0, quiet=0, hash_randomization=1, isolated=0, dev_mode=False, utf8_mode=0),
#  'float_repr_style': 'short',
#  'thread_info': sys.thread_info(name='pthread', lock='semaphore', version='NPTL 2.27'),
#  'modules': {'sys': <module 'sys' (built-in)>,
#   'builtins': <module 'builtins' (built-in)>,
#   '_frozen_importlib': <module 'importlib._bootstrap' (frozen)>,
#   '_imp': <module '_imp' (built-in)>,
#   '_thread': <module '_thread' (built-in)>,
#   '_warnings': <module '_warnings' (built-in)>,
#   '_weakref': <module '_weakref' (built-in)>,
#   'zipimport': <module 'zipimport' (built-in)>,
#   '_frozen_importlib_external': <module 'importlib._bootstrap_external' (frozen)>,
#   '_io': <module 'io' (built-in)>,
#   'marshal': <module 'marshal' (built-in)>,
#   'posix': <module 'posix' (built-in)>,
#   'encodings': <module 'encodings' from '/home/barbara/anaconda3/lib/python3.7/encodings/__init__.py'>,
#   'codecs': <module 'codecs' from '/home/barbara/anaconda3/lib/python3.7/codecs.py'>,
#   '_codecs': <module '_codecs' (built-in)>,
#   'encodings.aliases': <module 'encodings.aliases' from '/home/barbara/anaconda3/lib/python3.7/encodings/aliases.py'>,
#   'encodings.utf_8': <module 'encodings.utf_8' from '/home/barbara/anaconda3/lib/python3.7/encodings/utf_8.py'>,
#   '_signal': <module '_signal' (built-in)>,
#   '__main__': <module '__main__'>,
#   'encodings.latin_1': <module 'encodings.latin_1' from '/home/barbara/anaconda3/lib/python3.7/encodings/latin_1.py'>,
#   'io': <module 'io' from '/home/barbara/anaconda3/lib/python3.7/io.py'>,
#   'abc': <module 'abc' from '/home/barbara/anaconda3/lib/python3.7/abc.py'>,
#   '_abc': <module '_abc' (built-in)>,
#   '_bootlocale': <module '_bootlocale' from '/home/barbara/anaconda3/lib/python3.7/_bootlocale.py'>,
#   '_locale': <module '_locale' (built-in)>,
#   'site': <module 'site' from '/home/barbara/anaconda3/lib/python3.7/site.py'>,
#   'os': <module 'os' from '/home/barbara/anaconda3/lib/python3.7/os.py'>,
#   'stat': <module 'stat' from '/home/barbara/anaconda3/lib/python3.7/stat.py'>,
#   '_stat': <module '_stat' (built-in)>,
#   'posixpath': <module 'posixpath' from '/home/barbara/anaconda3/lib/python3.7/posixpath.py'>,
#   'genericpath': <module 'genericpath' from '/home/barbara/anaconda3/lib/python3.7/genericpath.py'>,
#   'os.path': <module 'posixpath' from '/home/barbara/anaconda3/lib/python3.7/posixpath.py'>,
#   '_collections_abc': <module '_collections_abc' from '/home/barbara/anaconda3/lib/python3.7/_collections_abc.py'>,
#   '_sitebuiltins': <module '_sitebuiltins' from '/home/barbara/anaconda3/lib/python3.7/_sitebuiltins.py'>,
#   'types': <module 'types' from '/home/barbara/anaconda3/lib/python3.7/types.py'>,
#   'importlib': <module 'importlib' from '/home/barbara/anaconda3/lib/python3.7/importlib/__init__.py'>,
#   'importlib._bootstrap': <module 'importlib._bootstrap' (frozen)>,
#   'importlib._bootstrap_external': <module 'importlib._bootstrap_external' (frozen)>,
#   'warnings': <module 'warnings' from '/home/barbara/anaconda3/lib/python3.7/warnings.py'>,
#   'importlib.util': <module 'importlib.util' from '/home/barbara/anaconda3/lib/python3.7/importlib/util.py'>,
#   'importlib.abc': <module 'importlib.abc' from '/home/barbara/anaconda3/lib/python3.7/importlib/abc.py'>,
#   'importlib.machinery': <module 'importlib.machinery' from '/home/barbara/anaconda3/lib/python3.7/importlib/machinery.py'>,
#   'contextlib': <module 'contextlib' from '/home/barbara/anaconda3/lib/python3.7/contextlib.py'>,
#   'collections': <module 'collections' from '/home/barbara/anaconda3/lib/python3.7/collections/__init__.py'>,
#   'operator': <module 'operator' from '/home/barbara/anaconda3/lib/python3.7/operator.py'>,
#   '_operator': <module '_operator' (built-in)>,
#   'keyword': <module 'keyword' from '/home/barbara/anaconda3/lib/python3.7/keyword.py'>,
#   'heapq': <module 'heapq' from '/home/barbara/anaconda3/lib/python3.7/heapq.py'>,
#   '_heapq': <module '_heapq' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_heapq.cpython-37m-x86_64-linux-gnu.so'>,
#   'itertools': <module 'itertools' (built-in)>,
#   'reprlib': <module 'reprlib' from '/home/barbara/anaconda3/lib/python3.7/reprlib.py'>,
#   '_collections': <module '_collections' (built-in)>,
#   'functools': <module 'functools' from '/home/barbara/anaconda3/lib/python3.7/functools.py'>,
#   '_functools': <module '_functools' (built-in)>,
#   'mpl_toolkits': <module 'mpl_toolkits' (namespace)>,
#   'sphinxcontrib': <module 'sphinxcontrib' from '/home/barbara/anaconda3/lib/python3.7/site-packages/sphinxcontrib/__init__.py'>,
#   'runpy': <module 'runpy' from '/home/barbara/anaconda3/lib/python3.7/runpy.py'>,
#   'pkgutil': <module 'pkgutil' from '/home/barbara/anaconda3/lib/python3.7/pkgutil.py'>,
#   'weakref': <module 'weakref' from '/home/barbara/anaconda3/lib/python3.7/weakref.py'>,
#   '_weakrefset': <module '_weakrefset' from '/home/barbara/anaconda3/lib/python3.7/_weakrefset.py'>,
#   'ipykernel': <module 'ipykernel' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipykernel/__init__.py'>,
#   'ipykernel._version': <module 'ipykernel._version' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipykernel/_version.py'>,
#   'ipykernel.connect': <module 'ipykernel.connect' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipykernel/connect.py'>,
#   '__future__': <module '__future__' from '/home/barbara/anaconda3/lib/python3.7/__future__.py'>,
#   'json': <module 'json' from '/home/barbara/anaconda3/lib/python3.7/json/__init__.py'>,
#   'json.decoder': <module 'json.decoder' from '/home/barbara/anaconda3/lib/python3.7/json/decoder.py'>,
#   're': <module 're' from '/home/barbara/anaconda3/lib/python3.7/re.py'>,
#   'enum': <module 'enum' from '/home/barbara/anaconda3/lib/python3.7/enum.py'>,
#   'sre_compile': <module 'sre_compile' from '/home/barbara/anaconda3/lib/python3.7/sre_compile.py'>,
#   '_sre': <module '_sre' (built-in)>,
#   'sre_parse': <module 'sre_parse' from '/home/barbara/anaconda3/lib/python3.7/sre_parse.py'>,
#   'sre_constants': <module 'sre_constants' from '/home/barbara/anaconda3/lib/python3.7/sre_constants.py'>,
#   'copyreg': <module 'copyreg' from '/home/barbara/anaconda3/lib/python3.7/copyreg.py'>,
#   'json.scanner': <module 'json.scanner' from '/home/barbara/anaconda3/lib/python3.7/json/scanner.py'>,
#   '_json': <module '_json' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_json.cpython-37m-x86_64-linux-gnu.so'>,
#   'json.encoder': <module 'json.encoder' from '/home/barbara/anaconda3/lib/python3.7/json/encoder.py'>,
#   'subprocess': <module 'subprocess' from '/home/barbara/anaconda3/lib/python3.7/subprocess.py'>,
#   'time': <module 'time' (built-in)>,
#   'signal': <module 'signal' from '/home/barbara/anaconda3/lib/python3.7/signal.py'>,
#   'errno': <module 'errno' (built-in)>,
#   '_posixsubprocess': <module '_posixsubprocess' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_posixsubprocess.cpython-37m-x86_64-linux-gnu.so'>,
#   'select': <module 'select' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/select.cpython-37m-x86_64-linux-gnu.so'>,
#   'selectors': <module 'selectors' from '/home/barbara/anaconda3/lib/python3.7/selectors.py'>,
#   'collections.abc': <module 'collections.abc' from '/home/barbara/anaconda3/lib/python3.7/collections/abc.py'>,
#   'math': <module 'math' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'>,
#   'threading': <module 'threading' from '/home/barbara/anaconda3/lib/python3.7/threading.py'>,
#   'traceback': <module 'traceback' from '/home/barbara/anaconda3/lib/python3.7/traceback.py'>,
#   'linecache': <module 'linecache' from '/home/barbara/anaconda3/lib/python3.7/linecache.py'>,
#   'tokenize': <module 'tokenize' from '/home/barbara/anaconda3/lib/python3.7/tokenize.py'>,
#   'token': <module 'token' from '/home/barbara/anaconda3/lib/python3.7/token.py'>,
#   'IPython': <module 'IPython' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/__init__.py'>,
#   'IPython.core': <module 'IPython.core' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/__init__.py'>,
#   'IPython.core.getipython': <module 'IPython.core.getipython' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/getipython.py'>,
#   'IPython.core.release': <module 'IPython.core.release' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/release.py'>,
#   'IPython.core.application': <module 'IPython.core.application' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/application.py'>,
#   'atexit': <module 'atexit' (built-in)>,
#   'copy': <module 'copy' from '/home/barbara/anaconda3/lib/python3.7/copy.py'>,
#   'glob': <module 'glob' from '/home/barbara/anaconda3/lib/python3.7/glob.py'>,
#   'fnmatch': <module 'fnmatch' from '/home/barbara/anaconda3/lib/python3.7/fnmatch.py'>,
#   'logging': <module 'logging' from '/home/barbara/anaconda3/lib/python3.7/logging/__init__.py'>,
#   'string': <module 'string' from '/home/barbara/anaconda3/lib/python3.7/string.py'>,
#   '_string': <module '_string' (built-in)>,
#   'shutil': <module 'shutil' from '/home/barbara/anaconda3/lib/python3.7/shutil.py'>,
#   'zlib': <module 'zlib' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/zlib.cpython-37m-x86_64-linux-gnu.so'>,
#   'bz2': <module 'bz2' from '/home/barbara/anaconda3/lib/python3.7/bz2.py'>,
#   '_compression': <module '_compression' from '/home/barbara/anaconda3/lib/python3.7/_compression.py'>,
#   '_bz2': <module '_bz2' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_bz2.cpython-37m-x86_64-linux-gnu.so'>,
#   'lzma': <module 'lzma' from '/home/barbara/anaconda3/lib/python3.7/lzma.py'>,
#   '_lzma': <module '_lzma' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_lzma.cpython-37m-x86_64-linux-gnu.so'>,
#   'pwd': <module 'pwd' (built-in)>,
#   'grp': <module 'grp' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/grp.cpython-37m-x86_64-linux-gnu.so'>,
#   'traitlets': <module 'traitlets' from '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/__init__.py'>,
#   'traitlets.traitlets': <module 'traitlets.traitlets' from '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py'>,
#   'inspect': <module 'inspect' from '/home/barbara/anaconda3/lib/python3.7/inspect.py'>,
#   'dis': <module 'dis' from '/home/barbara/anaconda3/lib/python3.7/dis.py'>,
#   'opcode': <module 'opcode' from '/home/barbara/anaconda3/lib/python3.7/opcode.py'>,
#   '_opcode': <module '_opcode' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_opcode.cpython-37m-x86_64-linux-gnu.so'>,
#   'six': <module 'six' from '/home/barbara/anaconda3/lib/python3.7/site-packages/six.py'>,
#   'struct': <module 'struct' from '/home/barbara/anaconda3/lib/python3.7/struct.py'>,
#   '_struct': <module '_struct' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_struct.cpython-37m-x86_64-linux-gnu.so'>,
#   'traitlets.utils': <module 'traitlets.utils' from '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/utils/__init__.py'>,
#   'traitlets.utils.getargspec': <module 'traitlets.utils.getargspec' from '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/utils/getargspec.py'>,
#   'traitlets.utils.importstring': <module 'traitlets.utils.importstring' from '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/utils/importstring.py'>,
#   'ipython_genutils': <module 'ipython_genutils' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipython_genutils/__init__.py'>,
#   'ipython_genutils._version': <module 'ipython_genutils._version' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipython_genutils/_version.py'>,
#   'ipython_genutils.py3compat': <module 'ipython_genutils.py3compat' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipython_genutils/py3compat.py'>,
#   'ipython_genutils.encoding': <module 'ipython_genutils.encoding' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipython_genutils/encoding.py'>,
#   'locale': <module 'locale' from '/home/barbara/anaconda3/lib/python3.7/locale.py'>,
#   'platform': <module 'platform' from '/home/barbara/anaconda3/lib/python3.7/platform.py'>,
#   'traitlets.utils.sentinel': <module 'traitlets.utils.sentinel' from '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/utils/sentinel.py'>,
#   'traitlets.utils.bunch': <module 'traitlets.utils.bunch' from '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/utils/bunch.py'>,
#   'traitlets._version': <module 'traitlets._version' from '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/_version.py'>,
#   'traitlets.config': <module 'traitlets.config' from '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/config/__init__.py'>,
#   'traitlets.config.application': <module 'traitlets.config.application' from '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py'>,
#   'decorator': <module 'decorator' from '/home/barbara/anaconda3/lib/python3.7/site-packages/decorator.py'>,
#   'traitlets.config.configurable': <module 'traitlets.config.configurable' from '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/config/configurable.py'>,
#   'traitlets.config.loader': <module 'traitlets.config.loader' from '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/config/loader.py'>,
#   'argparse': <module 'argparse' from '/home/barbara/anaconda3/lib/python3.7/argparse.py'>,
#   'gettext': <module 'gettext' from '/home/barbara/anaconda3/lib/python3.7/gettext.py'>,
#   'ast': <module 'ast' from '/home/barbara/anaconda3/lib/python3.7/ast.py'>,
#   '_ast': <module '_ast' (built-in)>,
#   'ipython_genutils.path': <module 'ipython_genutils.path' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipython_genutils/path.py'>,
#   'random': <module 'random' from '/home/barbara/anaconda3/lib/python3.7/random.py'>,
#   'hashlib': <module 'hashlib' from '/home/barbara/anaconda3/lib/python3.7/hashlib.py'>,
#   '_hashlib': <module '_hashlib' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_hashlib.cpython-37m-x86_64-linux-gnu.so'>,
#   '_blake2': <module '_blake2' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_blake2.cpython-37m-x86_64-linux-gnu.so'>,
#   '_sha3': <module '_sha3' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_sha3.cpython-37m-x86_64-linux-gnu.so'>,
#   'bisect': <module 'bisect' from '/home/barbara/anaconda3/lib/python3.7/bisect.py'>,
#   '_bisect': <module '_bisect' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_bisect.cpython-37m-x86_64-linux-gnu.so'>,
#   '_random': <module '_random' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_random.cpython-37m-x86_64-linux-gnu.so'>,
#   'ipython_genutils.text': <module 'ipython_genutils.text' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipython_genutils/text.py'>,
#   'textwrap': <module 'textwrap' from '/home/barbara/anaconda3/lib/python3.7/textwrap.py'>,
#   'ipython_genutils.importstring': <module 'ipython_genutils.importstring' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipython_genutils/importstring.py'>,
#   'IPython.core.crashhandler': <module 'IPython.core.crashhandler' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/crashhandler.py'>,
#   'pprint': <module 'pprint' from '/home/barbara/anaconda3/lib/python3.7/pprint.py'>,
#   'IPython.core.ultratb': <module 'IPython.core.ultratb' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py'>,
#   'pydoc': <module 'pydoc' from '/home/barbara/anaconda3/lib/python3.7/pydoc.py'>,
#   'urllib': <module 'urllib' from '/home/barbara/anaconda3/lib/python3.7/urllib/__init__.py'>,
#   'urllib.parse': <module 'urllib.parse' from '/home/barbara/anaconda3/lib/python3.7/urllib/parse.py'>,
#   'IPython.core.debugger': <module 'IPython.core.debugger' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/debugger.py'>,
#   'bdb': <module 'bdb' from '/home/barbara/anaconda3/lib/python3.7/bdb.py'>,
#   'IPython.utils': <module 'IPython.utils' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/__init__.py'>,
#   'IPython.utils.PyColorize': <module 'IPython.utils.PyColorize' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/PyColorize.py'>,
#   'IPython.utils.coloransi': <module 'IPython.utils.coloransi' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/coloransi.py'>,
#   'IPython.utils.ipstruct': <module 'IPython.utils.ipstruct' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/ipstruct.py'>,
#   'IPython.utils.colorable': <module 'IPython.utils.colorable' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/colorable.py'>,
#   'pygments': <module 'pygments' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/__init__.py'>,
#   'pygments.util': <module 'pygments.util' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/util.py'>,
#   'IPython.utils.py3compat': <module 'IPython.utils.py3compat' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/py3compat.py'>,
#   'IPython.utils.encoding': <module 'IPython.utils.encoding' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/encoding.py'>,
#   'IPython.core.excolors': <module 'IPython.core.excolors' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/excolors.py'>,
#   'IPython.testing': <module 'IPython.testing' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/testing/__init__.py'>,
#   'IPython.testing.skipdoctest': <module 'IPython.testing.skipdoctest' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/testing/skipdoctest.py'>,
#   'pdb': <module 'pdb' from '/home/barbara/anaconda3/lib/python3.7/pdb.py'>,
#   'cmd': <module 'cmd' from '/home/barbara/anaconda3/lib/python3.7/cmd.py'>,
#   'code': <module 'code' from '/home/barbara/anaconda3/lib/python3.7/code.py'>,
#   'codeop': <module 'codeop' from '/home/barbara/anaconda3/lib/python3.7/codeop.py'>,
#   'IPython.core.display_trap': <module 'IPython.core.display_trap' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/display_trap.py'>,
#   'IPython.utils.path': <module 'IPython.utils.path' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/path.py'>,
#   'IPython.utils.process': <module 'IPython.utils.process' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/process.py'>,
#   'IPython.utils._process_posix': <module 'IPython.utils._process_posix' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py'>,
#   'pexpect': <module 'pexpect' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pexpect/__init__.py'>,
#   'pexpect.exceptions': <module 'pexpect.exceptions' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pexpect/exceptions.py'>,
#   'pexpect.utils': <module 'pexpect.utils' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pexpect/utils.py'>,
#   'pexpect.expect': <module 'pexpect.expect' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pexpect/expect.py'>,
#   'pexpect.pty_spawn': <module 'pexpect.pty_spawn' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py'>,
#   'pty': <module 'pty' from '/home/barbara/anaconda3/lib/python3.7/pty.py'>,
#   'tty': <module 'tty' from '/home/barbara/anaconda3/lib/python3.7/tty.py'>,
#   'termios': <module 'termios' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/termios.cpython-37m-x86_64-linux-gnu.so'>,
#   'ptyprocess': <module 'ptyprocess' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ptyprocess/__init__.py'>,
#   'ptyprocess.ptyprocess': <module 'ptyprocess.ptyprocess' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ptyprocess/ptyprocess.py'>,
#   'fcntl': <module 'fcntl' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/fcntl.cpython-37m-x86_64-linux-gnu.so'>,
#   'resource': <module 'resource' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/resource.cpython-37m-x86_64-linux-gnu.so'>,
#   'ptyprocess.util': <module 'ptyprocess.util' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ptyprocess/util.py'>,
#   'pexpect.spawnbase': <module 'pexpect.spawnbase' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pexpect/spawnbase.py'>,
#   'pexpect.run': <module 'pexpect.run' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pexpect/run.py'>,
#   'IPython.utils._process_common': <module 'IPython.utils._process_common' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_common.py'>,
#   'shlex': <module 'shlex' from '/home/barbara/anaconda3/lib/python3.7/shlex.py'>,
#   'IPython.utils.decorators': <module 'IPython.utils.decorators' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/decorators.py'>,
#   'IPython.utils.data': <module 'IPython.utils.data' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/data.py'>,
#   'IPython.utils.terminal': <module 'IPython.utils.terminal' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/terminal.py'>,
#   'IPython.utils.sysinfo': <module 'IPython.utils.sysinfo' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/sysinfo.py'>,
#   'IPython.utils._sysinfo': <module 'IPython.utils._sysinfo' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/_sysinfo.py'>,
#   'IPython.core.profiledir': <module 'IPython.core.profiledir' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/profiledir.py'>,
#   'IPython.paths': <module 'IPython.paths' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/paths.py'>,
#   'tempfile': <module 'tempfile' from '/home/barbara/anaconda3/lib/python3.7/tempfile.py'>,
#   'IPython.utils.importstring': <module 'IPython.utils.importstring' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/importstring.py'>,
#   'IPython.terminal': <module 'IPython.terminal' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/terminal/__init__.py'>,
#   'IPython.terminal.embed': <module 'IPython.terminal.embed' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/terminal/embed.py'>,
#   'IPython.core.compilerop': <module 'IPython.core.compilerop' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/compilerop.py'>,
#   'IPython.core.magic_arguments': <module 'IPython.core.magic_arguments' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/magic_arguments.py'>,
#   'IPython.core.error': <module 'IPython.core.error' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/error.py'>,
#   'IPython.utils.text': <module 'IPython.utils.text' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/text.py'>,
#   'pathlib': <module 'pathlib' from '/home/barbara/anaconda3/lib/python3.7/pathlib.py'>,
#   'ntpath': <module 'ntpath' from '/home/barbara/anaconda3/lib/python3.7/ntpath.py'>,
#   'IPython.core.magic': <module 'IPython.core.magic' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py'>,
#   'getopt': <module 'getopt' from '/home/barbara/anaconda3/lib/python3.7/getopt.py'>,
#   'IPython.core.oinspect': <module 'IPython.core.oinspect' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/oinspect.py'>,
#   'IPython.core.page': <module 'IPython.core.page' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/page.py'>,
#   'IPython.core.display': <module 'IPython.core.display' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/display.py'>,
#   'binascii': <module 'binascii' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/binascii.cpython-37m-x86_64-linux-gnu.so'>,
#   'mimetypes': <module 'mimetypes' from '/home/barbara/anaconda3/lib/python3.7/mimetypes.py'>,
#   'IPython.lib': <module 'IPython.lib' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/lib/__init__.py'>,
#   'IPython.lib.security': <module 'IPython.lib.security' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/lib/security.py'>,
#   'getpass': <module 'getpass' from '/home/barbara/anaconda3/lib/python3.7/getpass.py'>,
#   'IPython.lib.pretty': <module 'IPython.lib.pretty' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py'>,
#   'datetime': <module 'datetime' from '/home/barbara/anaconda3/lib/python3.7/datetime.py'>,
#   '_datetime': <module '_datetime' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_datetime.cpython-37m-x86_64-linux-gnu.so'>,
#   'IPython.utils.openpy': <module 'IPython.utils.openpy' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/openpy.py'>,
#   'IPython.utils.dir2': <module 'IPython.utils.dir2' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/dir2.py'>,
#   'IPython.utils.wildcard': <module 'IPython.utils.wildcard' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/wildcard.py'>,
#   'pygments.lexers': <module 'pygments.lexers' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/lexers/__init__.py'>,
#   'pygments.lexers._mapping': <module 'pygments.lexers._mapping' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/lexers/_mapping.py'>,
#   'pygments.modeline': <module 'pygments.modeline' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/modeline.py'>,
#   'pygments.plugin': <module 'pygments.plugin' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/plugin.py'>,
#   'pygments.lexers.python': <module 'pygments.lexers.python' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/lexers/python.py'>,
#   'pygments.lexer': <module 'pygments.lexer' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/lexer.py'>,
#   'pygments.filter': <module 'pygments.filter' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/filter.py'>,
#   'pygments.filters': <module 'pygments.filters' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/filters/__init__.py'>,
#   'pygments.token': <module 'pygments.token' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/token.py'>,
#   'pygments.regexopt': <module 'pygments.regexopt' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/regexopt.py'>,
#   'pygments.unistring': <module 'pygments.unistring' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/unistring.py'>,
#   'pygments.formatters': <module 'pygments.formatters' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/formatters/__init__.py'>,
#   'pygments.formatters._mapping': <module 'pygments.formatters._mapping' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/formatters/_mapping.py'>,
#   'pygments.formatters.html': <module 'pygments.formatters.html' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/formatters/html.py'>,
#   'pygments.formatter': <module 'pygments.formatter' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/formatter.py'>,
#   'pygments.styles': <module 'pygments.styles' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/styles/__init__.py'>,
#   'IPython.core.inputtransformer2': <module 'IPython.core.inputtransformer2' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/inputtransformer2.py'>,
#   'typing': <module 'typing' from '/home/barbara/anaconda3/lib/python3.7/typing.py'>,
#   'typing.io': typing.io,
#   'typing.re': typing.re,
#   'IPython.core.interactiveshell': <module 'IPython.core.interactiveshell' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py'>,
#   'asyncio': <module 'asyncio' from '/home/barbara/anaconda3/lib/python3.7/asyncio/__init__.py'>,
#   'asyncio.base_events': <module 'asyncio.base_events' from '/home/barbara/anaconda3/lib/python3.7/asyncio/base_events.py'>,
#   'concurrent': <module 'concurrent' from '/home/barbara/anaconda3/lib/python3.7/concurrent/__init__.py'>,
#   'concurrent.futures': <module 'concurrent.futures' from '/home/barbara/anaconda3/lib/python3.7/concurrent/futures/__init__.py'>,
#   'concurrent.futures._base': <module 'concurrent.futures._base' from '/home/barbara/anaconda3/lib/python3.7/concurrent/futures/_base.py'>,
#   'socket': <module 'socket' from '/home/barbara/anaconda3/lib/python3.7/socket.py'>,
#   '_socket': <module '_socket' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_socket.cpython-37m-x86_64-linux-gnu.so'>,
#   'ssl': <module 'ssl' from '/home/barbara/anaconda3/lib/python3.7/ssl.py'>,
#   '_ssl': <module '_ssl' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_ssl.cpython-37m-x86_64-linux-gnu.so'>,
#   'base64': <module 'base64' from '/home/barbara/anaconda3/lib/python3.7/base64.py'>,
#   'asyncio.constants': <module 'asyncio.constants' from '/home/barbara/anaconda3/lib/python3.7/asyncio/constants.py'>,
#   'asyncio.coroutines': <module 'asyncio.coroutines' from '/home/barbara/anaconda3/lib/python3.7/asyncio/coroutines.py'>,
#   'asyncio.base_futures': <module 'asyncio.base_futures' from '/home/barbara/anaconda3/lib/python3.7/asyncio/base_futures.py'>,
#   'asyncio.format_helpers': <module 'asyncio.format_helpers' from '/home/barbara/anaconda3/lib/python3.7/asyncio/format_helpers.py'>,
#   'asyncio.log': <module 'asyncio.log' from '/home/barbara/anaconda3/lib/python3.7/asyncio/log.py'>,
#   'asyncio.events': <module 'asyncio.events' from '/home/barbara/anaconda3/lib/python3.7/asyncio/events.py'>,
#   'contextvars': <module 'contextvars' from '/home/barbara/anaconda3/lib/python3.7/contextvars.py'>,
#   '_contextvars': <module '_contextvars' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_contextvars.cpython-37m-x86_64-linux-gnu.so'>,
#   'asyncio.base_tasks': <module 'asyncio.base_tasks' from '/home/barbara/anaconda3/lib/python3.7/asyncio/base_tasks.py'>,
#   '_asyncio': <module '_asyncio' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_asyncio.cpython-37m-x86_64-linux-gnu.so'>,
#   'asyncio.futures': <module 'asyncio.futures' from '/home/barbara/anaconda3/lib/python3.7/asyncio/futures.py'>,
#   'asyncio.protocols': <module 'asyncio.protocols' from '/home/barbara/anaconda3/lib/python3.7/asyncio/protocols.py'>,
#   'asyncio.sslproto': <module 'asyncio.sslproto' from '/home/barbara/anaconda3/lib/python3.7/asyncio/sslproto.py'>,
#   'asyncio.transports': <module 'asyncio.transports' from '/home/barbara/anaconda3/lib/python3.7/asyncio/transports.py'>,
#   'asyncio.tasks': <module 'asyncio.tasks' from '/home/barbara/anaconda3/lib/python3.7/asyncio/tasks.py'>,
#   'asyncio.locks': <module 'asyncio.locks' from '/home/barbara/anaconda3/lib/python3.7/asyncio/locks.py'>,
#   'asyncio.runners': <module 'asyncio.runners' from '/home/barbara/anaconda3/lib/python3.7/asyncio/runners.py'>,
#   'asyncio.queues': <module 'asyncio.queues' from '/home/barbara/anaconda3/lib/python3.7/asyncio/queues.py'>,
#   'asyncio.streams': <module 'asyncio.streams' from '/home/barbara/anaconda3/lib/python3.7/asyncio/streams.py'>,
#   'asyncio.subprocess': <module 'asyncio.subprocess' from '/home/barbara/anaconda3/lib/python3.7/asyncio/subprocess.py'>,
#   'asyncio.unix_events': <module 'asyncio.unix_events' from '/home/barbara/anaconda3/lib/python3.7/asyncio/unix_events.py'>,
#   'asyncio.base_subprocess': <module 'asyncio.base_subprocess' from '/home/barbara/anaconda3/lib/python3.7/asyncio/base_subprocess.py'>,
#   'asyncio.selector_events': <module 'asyncio.selector_events' from '/home/barbara/anaconda3/lib/python3.7/asyncio/selector_events.py'>,
#   'pickleshare': <module 'pickleshare' from '/home/barbara/anaconda3/lib/python3.7/site-packages/pickleshare.py'>,
#   'pickle': <module 'pickle' from '/home/barbara/anaconda3/lib/python3.7/pickle.py'>,
#   '_compat_pickle': <module '_compat_pickle' from '/home/barbara/anaconda3/lib/python3.7/_compat_pickle.py'>,
#   '_pickle': <module '_pickle' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_pickle.cpython-37m-x86_64-linux-gnu.so'>,
#   'IPython.core.prefilter': <module 'IPython.core.prefilter' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/prefilter.py'>,
#   'IPython.core.autocall': <module 'IPython.core.autocall' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/autocall.py'>,
#   'IPython.core.macro': <module 'IPython.core.macro' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/macro.py'>,
#   'IPython.core.splitinput': <module 'IPython.core.splitinput' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/splitinput.py'>,
#   'IPython.core.alias': <module 'IPython.core.alias' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/alias.py'>,
#   'IPython.core.builtin_trap': <module 'IPython.core.builtin_trap' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/builtin_trap.py'>,
#   'IPython.core.events': <module 'IPython.core.events' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/events.py'>,
#   'backcall': <module 'backcall' from '/home/barbara/anaconda3/lib/python3.7/site-packages/backcall/__init__.py'>,
#   'backcall.backcall': <module 'backcall.backcall' from '/home/barbara/anaconda3/lib/python3.7/site-packages/backcall/backcall.py'>,
#   'IPython.core.displayhook': <module 'IPython.core.displayhook' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/displayhook.py'>,
#   'IPython.core.displaypub': <module 'IPython.core.displaypub' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/displaypub.py'>,
#   'IPython.core.extensions': <module 'IPython.core.extensions' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/extensions.py'>,
#   'IPython.core.formatters': <module 'IPython.core.formatters' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py'>,
#   'IPython.utils.sentinel': <module 'IPython.utils.sentinel' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/sentinel.py'>,
#   'IPython.core.history': <module 'IPython.core.history' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/history.py'>,
#   'sqlite3': <module 'sqlite3' from '/home/barbara/anaconda3/lib/python3.7/sqlite3/__init__.py'>,
#   'sqlite3.dbapi2': <module 'sqlite3.dbapi2' from '/home/barbara/anaconda3/lib/python3.7/sqlite3/dbapi2.py'>,
#   '_sqlite3': <module '_sqlite3' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_sqlite3.cpython-37m-x86_64-linux-gnu.so'>,
#   'IPython.core.logger': <module 'IPython.core.logger' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/logger.py'>,
#   'IPython.core.payload': <module 'IPython.core.payload' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/payload.py'>,
#   'IPython.core.usage': <module 'IPython.core.usage' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/usage.py'>,
#   'IPython.display': <module 'IPython.display' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/display.py'>,
#   'IPython.lib.display': <module 'IPython.lib.display' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/lib/display.py'>,
#   'html': <module 'html' from '/home/barbara/anaconda3/lib/python3.7/html/__init__.py'>,
#   'html.entities': <module 'html.entities' from '/home/barbara/anaconda3/lib/python3.7/html/entities.py'>,
#   'IPython.utils.io': <module 'IPython.utils.io' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/io.py'>,
#   'IPython.utils.capture': <module 'IPython.utils.capture' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/capture.py'>,
#   'IPython.utils.strdispatch': <module 'IPython.utils.strdispatch' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/strdispatch.py'>,
#   'IPython.core.hooks': <module 'IPython.core.hooks' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/hooks.py'>,
#   'IPython.utils.syspathcontext': <module 'IPython.utils.syspathcontext' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/syspathcontext.py'>,
#   'IPython.utils.tempdir': <module 'IPython.utils.tempdir' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/tempdir.py'>,
#   'IPython.utils.contexts': <module 'IPython.utils.contexts' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils/contexts.py'>,
#   'IPython.core.async_helpers': <module 'IPython.core.async_helpers' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py'>,
#   'IPython.terminal.interactiveshell': <module 'IPython.terminal.interactiveshell' from '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/terminal/interactiveshell.py'>,
#   'prompt_toolkit': <module 'prompt_toolkit' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/__init__.py'>,
#   'prompt_toolkit.application': <module 'prompt_toolkit.application' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/application/__init__.py'>,
#   'prompt_toolkit.application.application': <module 'prompt_toolkit.application.application' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/application/application.py'>,
#   'prompt_toolkit.buffer': <module 'prompt_toolkit.buffer' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/buffer.py'>,
#   'prompt_toolkit.application.current': <module 'prompt_toolkit.application.current' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/application/current.py'>,
#   'prompt_toolkit.eventloop': <module 'prompt_toolkit.eventloop' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/eventloop/__init__.py'>,
#   'prompt_toolkit.eventloop.base': <module 'prompt_toolkit.eventloop.base' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/eventloop/base.py'>,
#   'prompt_toolkit.log': <module 'prompt_toolkit.log' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/log.py'>,
#   'prompt_toolkit.eventloop.coroutine': <module 'prompt_toolkit.eventloop.coroutine' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/eventloop/coroutine.py'>,
#   'prompt_toolkit.eventloop.defaults': <module 'prompt_toolkit.eventloop.defaults' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/eventloop/defaults.py'>,
#   'prompt_toolkit.utils': <module 'prompt_toolkit.utils' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/utils.py'>,
#   'six.moves': <module 'six.moves' (<six._SixMetaPathImporter object at 0x7f1ec5a229b0>)>,
#   'wcwidth': <module 'wcwidth' from '/home/barbara/anaconda3/lib/python3.7/site-packages/wcwidth/__init__.py'>,
#   'wcwidth.wcwidth': <module 'wcwidth.wcwidth' from '/home/barbara/anaconda3/lib/python3.7/site-packages/wcwidth/wcwidth.py'>,
#   'wcwidth.table_wide': <module 'wcwidth.table_wide' from '/home/barbara/anaconda3/lib/python3.7/site-packages/wcwidth/table_wide.py'>,
#   'wcwidth.table_zero': <module 'wcwidth.table_zero' from '/home/barbara/anaconda3/lib/python3.7/site-packages/wcwidth/table_zero.py'>,
#   'prompt_toolkit.cache': <module 'prompt_toolkit.cache' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/cache.py'>,
#   'prompt_toolkit.eventloop.future': <module 'prompt_toolkit.eventloop.future' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/eventloop/future.py'>,
#   'prompt_toolkit.eventloop.context': <module 'prompt_toolkit.eventloop.context' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/eventloop/context.py'>,
#   'prompt_toolkit.eventloop.async_generator': <module 'prompt_toolkit.eventloop.async_generator' from '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/eventloop/async_generator.py'>,
#   'queue': <module 'queue' from '/home/barbara/anaconda3/lib/python3.7/queue.py'>,
#   '_queue': <module '_queue' from '/home/barbara/anaconda3/lib/python3.7/lib-dynload/_queue.cpython-37m-x86_64-linux-gnu.so'>,
#   'six.moves.queue': <module 'queue' from '/home/barbara/anaconda3/lib/python3.7/queue.py'>,
# ...
#   'ipywidgets.widgets.widget_selection': <module 'ipywidgets.widgets.widget_selection' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget_selection.py'>,
#   'ipywidgets.widgets.widget_selectioncontainer': <module 'ipywidgets.widgets.widget_selectioncontainer' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget_selectioncontainer.py'>,
#   'ipywidgets.widgets.widget_string': <module 'ipywidgets.widgets.widget_string' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget_string.py'>,
#   'ipywidgets.widgets.widget_controller': <module 'ipywidgets.widgets.widget_controller' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget_controller.py'>,
#   'ipywidgets.widgets.interaction': <module 'ipywidgets.widgets.interaction' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/interaction.py'>,
#   'ipywidgets.widgets.widget_link': <module 'ipywidgets.widgets.widget_link' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget_link.py'>,
#   'ipywidgets.widgets.widget_media': <module 'ipywidgets.widgets.widget_media' from '/home/barbara/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget_media.py'>},
#  'stderr': <ipykernel.iostream.OutStream at 0x7f1ec2f55400>,
#  '__stderr__': <_io.TextIOWrapper name='<stderr>' mode='w' encoding='UTF-8'>,
#  'meta_path': [_frozen_importlib.BuiltinImporter,
#   _frozen_importlib.FrozenImporter,
#   _frozen_importlib_external.PathFinder,
#   <six._SixMetaPathImporter at 0x7f1ec5a229b0>],
#  'path_importer_cache': {'/home/barbara/anaconda3/lib/python37.zip': None,
#   '/home/barbara/anaconda3/lib/python3.7': FileFinder('/home/barbara/anaconda3/lib/python3.7'),
#   '/home/barbara/anaconda3/lib/python3.7/encodings': FileFinder('/home/barbara/anaconda3/lib/python3.7/encodings'),
#   '/home/barbara/anaconda3/lib/python3.7/importlib': FileFinder('/home/barbara/anaconda3/lib/python3.7/importlib'),
#   '/home/barbara/anaconda3/lib/python3.7/lib-dynload': FileFinder('/home/barbara/anaconda3/lib/python3.7/lib-dynload'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages'),
#   '/home/barbara/Curso de Python - ICMC/Modulo 2': FileFinder('/home/barbara/Curso de Python - ICMC/Modulo 2'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/ipykernel': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/ipykernel'),
#   '/home/barbara/anaconda3/lib/python3.7/json': FileFinder('/home/barbara/anaconda3/lib/python3.7/json'),
#   '/home/barbara/anaconda3/lib/python3.7/collections': FileFinder('/home/barbara/anaconda3/lib/python3.7/collections'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/IPython'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/extensions': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/extensions'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/utils': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/utils'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/ipython_genutils': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/ipython_genutils'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/config': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/traitlets/config'),
#   '/home/barbara/anaconda3/lib/python3.7/urllib': FileFinder('/home/barbara/anaconda3/lib/python3.7/urllib'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/utils'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/pygments'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/testing': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/testing'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/pexpect': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/pexpect'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/ptyprocess': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/ptyprocess'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/terminal': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/terminal'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/lib': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/lib'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/lexers': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/lexers'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/formatters': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/pygments/formatters'),
#   '/home/barbara/anaconda3/lib/python3.7/asyncio': FileFinder('/home/barbara/anaconda3/lib/python3.7/asyncio'),
#   '/home/barbara/anaconda3/lib/python3.7/concurrent': FileFinder('/home/barbara/anaconda3/lib/python3.7/concurrent'),
#   '/home/barbara/anaconda3/lib/python3.7/concurrent/futures': FileFinder('/home/barbara/anaconda3/lib/python3.7/concurrent/futures'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/backcall': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/backcall'),
#   '/home/barbara/anaconda3/lib/python3.7/sqlite3': FileFinder('/home/barbara/anaconda3/lib/python3.7/sqlite3'),
#   '/home/barbara/anaconda3/lib/python3.7/html': FileFinder('/home/barbara/anaconda3/lib/python3.7/html'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/application': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/application'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/eventloop': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/eventloop'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/wcwidth': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/wcwidth'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/filters': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/filters'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/clipboard': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/clipboard'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/completion': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/completion'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/key_binding': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/key_binding'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/input': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/input'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/key_binding/bindings': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/key_binding/bindings'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/layout': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/layout'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/formatted_text': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/formatted_text'),
#   '/home/barbara/anaconda3/lib/python3.7/xml': FileFinder('/home/barbara/anaconda3/lib/python3.7/xml'),
#   '/home/barbara/anaconda3/lib/python3.7/xml/dom': FileFinder('/home/barbara/anaconda3/lib/python3.7/xml/dom'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/output': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/output'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/styles': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/styles'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/lexers': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/lexers'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/shortcuts': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/shortcuts'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/widgets': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/widgets'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/shortcuts/progress_bar': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/prompt_toolkit/shortcuts/progress_bar'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/jedi': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/jedi'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/parso': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/parso'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/parso/pgen2': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/parso/pgen2'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/parso/python': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/parso/python'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/colorama': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/colorama'),
#   '/home/barbara/anaconda3/lib/python3.7/ctypes': FileFinder('/home/barbara/anaconda3/lib/python3.7/ctypes'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/jedi/api': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/jedi/api'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/jedi/evaluate': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/jedi/evaluate'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/jedi/common': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/jedi/common'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/jedi/evaluate/compiled': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/jedi/evaluate/compiled'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/jedi/evaluate/context': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/jedi/evaluate/context'),
#   '/home/barbara/anaconda3/lib/python3.7/pydoc_data': FileFinder('/home/barbara/anaconda3/lib/python3.7/pydoc_data'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/jedi/evaluate/compiled/subprocess': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/jedi/evaluate/compiled/subprocess'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/magics': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/core/magics'),
#   '/home/barbara/anaconda3/lib/python3.7/http': FileFinder('/home/barbara/anaconda3/lib/python3.7/http'),
#   '/home/barbara/anaconda3/lib/python3.7/email': FileFinder('/home/barbara/anaconda3/lib/python3.7/email'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/jupyter_client': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/jupyter_client'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/zmq': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/zmq'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/zmq/backend': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/zmq/backend'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/zmq/backend/cython': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/zmq/backend/cython'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/zmq/sugar': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/zmq/sugar'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/zmq/utils': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/zmq/utils'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/jupyter_core': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/jupyter_core'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/jupyter_client/blocking': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/jupyter_client/blocking'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/tornado': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/tornado'),
#   '/home/barbara/anaconda3/lib/python3.7/logging': FileFinder('/home/barbara/anaconda3/lib/python3.7/logging'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/zmq/eventloop': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/zmq/eventloop'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/tornado/platform': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/tornado/platform'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/dateutil': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/dateutil'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/dateutil/parser': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/dateutil/parser'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/dateutil/tz': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/dateutil/tz'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/ipykernel/comm': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/ipykernel/comm'),
#   '/home/barbara/.ipython': FileFinder('/home/barbara/.ipython'),
#   '/home/barbara/.ipython/extensions': FileFinder('/home/barbara/.ipython/extensions'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/ipywidgets': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/ipywidgets'),
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets': FileFinder('/home/barbara/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets')},
#  'path_hooks': [zipimport.zipimporter,
#   <function _frozen_importlib_external.FileFinder.path_hook.<locals>.path_hook_for_FileFinder(path)>],
#  'path': ['/home/barbara/Curso de Python - ICMC/Modulo 2',
#   '/home/barbara/anaconda3/lib/python37.zip',
#   '/home/barbara/anaconda3/lib/python3.7',
#   '/home/barbara/anaconda3/lib/python3.7/lib-dynload',
#   '',
#   '/home/barbara/anaconda3/lib/python3.7/site-packages',
#   '/home/barbara/anaconda3/lib/python3.7/site-packages/IPython/extensions',
#   '/home/barbara/.ipython'],
#  'executable': '/home/barbara/anaconda3/bin/python',
#  'prefix': '/home/barbara/anaconda3',
#  'base_prefix': '/home/barbara/anaconda3',
#  'exec_prefix': '/home/barbara/anaconda3',
#  'base_exec_prefix': '/home/barbara/anaconda3',
#  'argv': ['/home/barbara/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py',
#   '-f',
#   '/run/user/1000/jupyter/kernel-5d6805b6-fd23-4bb1-923a-2bded95f76e2.json'],
#  'warnoptions': [],
#  '_xoptions': {},
#  'dont_write_bytecode': False,
#  '__stdin__': <_io.TextIOWrapper name='<stdin>' mode='r' encoding='UTF-8'>,
#  'stdin': <_io.TextIOWrapper name='<stdin>' mode='r' encoding='UTF-8'>,
#  '__stdout__': <_io.TextIOWrapper name='<stdout>' mode='w' encoding='UTF-8'>,
#  'stdout': <ipykernel.iostream.OutStream at 0x7f1ec2f556d8>,
#  '_home': None,
#  '__interactivehook__': <function site.enablerlcompleter.<locals>.register_readline()>,
#  'ps1': 'In : ',
#  'ps2': '...: ',
#  'ps3': 'Out: '}

# %% [markdown]
# Módulos podem importar outros módulos que também podem importar outros módulos
# $$
# \fbox{a.py}\xrightarrow{\text{importa}}\fbox{b.py}\xrightarrow{\text{importa}}\fbox{c.py}
# $$
# Atributos de _c.py_ pode ser acessado pelo módulo _b.py_ usando a notação de atributo `b.c.atributo` no arquivo _a.py_

# %% [markdown]
# ### Caminho de Busca de um Módulo
# Quando importa um módulo, Python usa um caminho de busca para determinar a localização do módulo
#
# O caminho de busca compreende:
# - Diretório de trabalho (local do arquivo no top-level ou diretório atual de trabalho)
# - Diretórios do PYTHONPATH
# - Diretórios padrão de bibliotecas
# - Os conteúdos de qualquer arquivo .pth
# - O diretório site-packages
#
# O caminho de busca se encontra disponível em sys.path

# %%
import sys
sys.path
# Out:
# ['/mnt/Dados/Documentos/curso-nonato',
#  '/home/dreadnought/anaconda3/envs/py37/lib/python37.zip',
#  '/home/dreadnought/anaconda3/envs/py37/lib/python3.7',
#  '/home/dreadnought/anaconda3/envs/py37/lib/python3.7/lib-dynload',
#  '',
#  '/home/dreadnought/anaconda3/envs/py37/lib/python3.7/site-packages',
#  '/home/dreadnought/anaconda3/envs/py37/lib/python3.7/site-packages/IPython/extensions',
#  '/home/dreadnought/.ipython']

# %% [markdown]
# ### Special Module Variables
# - \_var:
# Variáveis começando com underscore não serão importandas quando usado from *
# - \__all\__:
# Nome de variáveis nessa lista serão importandos quando usado from *
# - \__name\__:
# Atribuído como nome do módulo ou “&lowbar;&lowbar;main&lowbar;&lowbar;” se o módulo for o top-level
# ```python
# if __name__ == ‘__main__’:
# # só é executado quando esse arquivo é chamado, nunca quando importado
# ```

# %%
# %%writefile mymodule.py

# variáveis a serem importadas

__all__ = ['variable1','variable2'] # declarar as variáveis

_variable0 = '_variable0: not imported'

variable1 = 'variable1: imported'
variable2 = 'variable2: imported'

variable3 = 'variable3: not imported'

if __name__ == '__main__':
    print('Module configuration')
    print(_variable0,variable1,variable2,variable2,)
# Out:
# Writing mymodule.py

# %%
from mymodule import * # a variável passa a fazer parte do código, pouco usado.

print(variable1)
print(variable2)
print(variable3)
# Out:
# variable1: imported
# variable2: imported
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ee17e2ab1397> in <module>
#       3 print(variable1)
#       4 print(variable2)
# ----> 5 print(variable3)
#
# NameError: name 'variable3' is not defined

# %%
# !python3 mymodule.py
# Out:
# Module configuration
# _variable0: not imported variable1: imported variable2: imported variable2: imported

# %%
import mymodule # cria um objeto, mais usado.

print(mymodule._variable0)
print(mymodule.variable1)
print(mymodule.variable2)
print(mymodule.variable3)
# Out:
# _variable0: not imported
# variable1: imported
# variable2: imported
# variable3: not imported

# %% [markdown]
# ---
# ## Exceções
# Uma exceção é um evento que ocorre durante a execução de um programa e que desvia o curso normal das instruções do programa. <br>
# Quando um programa em Python encontra uma situação que não pode lidar, ele aciona uma exceção.
#
# - Uma exceção é um  __Objeto Python__ que representa um erro
# - O comportamento padrão para exceções é terminar a execução
# - Lidar com exceções é muito importante para criar um código robusto

# %% [markdown]
# Código que pode levantar uma exceção são tipicamente declarados em um bloco<br> ``try-except-else``
# ```python
# try:
# 		statements
# except name1:
# 		statements
# except (name2, name3):
# 		statements
# except name4 as var:
# 		statements
# except:
# 		statements
# else:
# 		statements
# finally:
# 		statements
# ```

# %%
def check_index(v,i): # v é uma lista
    return(v[i])

x = [0,1,2,3]

try: 
    check_index(x, 5) 
except IndexError: # todas as exceções estão listadas em uma tabela
    print('got exception')
# Out:
# got exception

# %% [markdown]
# - Uma simples declaração `try` pode ter várias declarações do tipo `except`
#   - Isso é útil quando o bloco `try` contém declarações que podem levantar diferentes tipos de exceções
# - Uma declaração `except` pode captar um única exceção ou uma lista de exceções
# - A exceção pode ser atribuída a uma variável
# - Você pode incluir uma exceção genérica que pode captar qualquer tipo de exceção
# - As declarações de exceção são testadas de cima para baixo

# %% [markdown]
# __Atenção__:
# - Após as cláusulas `except`, você pode incluir uma cláusula` else` que é executada se o código no bloco `try` não gerar uma exceção
# - O bloco `else` é um bom lugar para código que não precisa da proteção do bloco `try`
# - O bloco `finally` é sempre executado, independentemente de uma exceção ocorrer ou não

# %% [markdown]
# A instrução `raise` é usada para forçar uma exceção especificada a ocorrer

# %%
raise NameError('My error')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-b8324f73008d> in <module>
# ----> 1 raise NameError('My error')
#
# NameError: My error

# %% [markdown]
# ### Exceções padrão
# Python traz uma dúzia de classes de exceções diferentes, todas elas tendo a exceção `Exception` como superclasse.
# [Exception Class Hierarchy](https://airbrake.io/blog/python-exception-handling/class-hierarchy)

# %%
def dividing(x,y):
    if y == 0.0:
        raise ZeroDivisionError() # raise força uma exceção
    else:
        return(x/y)

a = 3
b = 0
    
try:
    result = dividing(a,b)
except ZeroDivisionError:
    print("---division by zero!---")
else:
    print("result is", result)
finally:
    print("executing finally clause")
# Out:
# ---division by zero!---
# executing finally clause

# %% [markdown]
# ### Exceções definidas pelo usuário
# Usuários podem definir suas próprias exceções usando a exceção `Exception` como superclasee.

# %%
# Criando uma classe exceção que herda a classe exceção do Python
class MyException(Exception):
    def __str__(self):
        return('This is my exception!\n')
    
def is_equal(a,b):
    if a != b:
        raise MyException()
    else:
        print('Equal')

is_equal(3,3)
        
# try:
#     is_equal(2,3)
# except MyException:
#     print('Not Equal')
# else:
#     pass
# Out:
# Equal

# %%
is_equal(3,2) # erro do python e depois do myexception
# Out:
# ---------------------------------------------------------------------------
# MyException                               Traceback (most recent call last)
# <ipython-input-13-c9742d6316e3> in <module>
# ----> 1 is_equal(3,2)
#
# <ipython-input-12-09728a8e6b53> in is_equal(a, b)
#       6 def is_equal(a,b):
#       7     if a != b:
# ----> 8         raise MyException()
#       9     else:
#      10         print('Equal')
#
# MyException: This is my exception!
